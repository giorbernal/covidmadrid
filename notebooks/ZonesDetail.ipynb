# %% [markdown]
# # Getafe, Leganés y Móstoles al Detalle

# %%
WORK_FOLDER='../'

# %%
import sys
sys.path.append(WORK_FOLDER)

# %%
#from dbfread import DBF # Borrar
from utils.helper import sample_coordinates, checkPositions
from utils.helper import loadCovidData, comparePlaces, plotPlaces

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# ## Carga de datos de la fuente oficial

# %%
#!wget https://datos.comunidad.madrid/catalogo/dataset/b3d55e40-8263-4c0b-827d-2bb23b5e7bab/resource/b7b9edb4-0c70-47d3-9c64-8c4913830a24/download/covid19_tia_zonas_basicas_salud.csv  --no-check-certificat -O ../datasets/covid19_tia_zonas_basicas_salud.csv

# %%
df=loadCovidData(dataset='zonas', prefix=WORK_FOLDER)

# %% [markdown]
# ## Obtener zonas de salud de una localidad concreta a través de una muestra representativa de localizaciones

# %% [markdown]
# ### Getafe

# %%
health_zones_getafe = checkPositions(sample_coordinates['Getafe'], prefix=WORK_FOLDER)

# %%
comparePlaces(df, health_zones_getafe, dataset='zonas')

# %%
plotPlaces(df, health_zones_getafe, agg_factor=1, dataset='zonas')
# Out:
# Error en Juan de la Cierva!!: Axis limits cannot be NaN or Inf
# Error en Las Ciudades!!: Axis limits cannot be NaN or Inf
# Error en Getafe Norte!!: Axis limits cannot be NaN or Inf
# Error en Las Margaritas!!: Axis limits cannot be NaN or Inf
# Error en El Bercial!!: Axis limits cannot be NaN or Inf
# Error en El Greco!!: Axis limits cannot be NaN or Inf
# Error en Sector III!!: Axis limits cannot be NaN or Inf
# Error en Sánchez Morate!!: Axis limits cannot be NaN or Inf
# Error en Perales del Río!!: Axis limits cannot be NaN or Inf
# ../utils/helper.py:186: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(N,2,index)

# %% [markdown]
# ### Leganés

# %%
health_zones_leganes = checkPositions(sample_coordinates['Leganés'], prefix=WORK_FOLDER)

# %%
comparePlaces(df, health_zones_leganes,dataset='zonas')

# %%
plotPlaces(df, health_zones_leganes, agg_factor=1, dataset='zonas')
# Out:
# Error en Mendiguchía Carriche!!: Axis limits cannot be NaN or Inf
# Error en Europa!!: Axis limits cannot be NaN or Inf
# Error en María Montessori!!: Axis limits cannot be NaN or Inf
# Error en Leganés Norte!!: Axis limits cannot be NaN or Inf
# Error en Los Pedroches!!: Axis limits cannot be NaN or Inf
# Error en Palomares!!: Axis limits cannot be NaN or Inf
# Error en María Jesús Hereza!!: Axis limits cannot be NaN or Inf
# Error en Pizarro!!: Axis limits cannot be NaN or Inf
# Error en Huerta de Los Frailes!!: Axis limits cannot be NaN or Inf

# %% [markdown]
# ### Móstoles

# %%
health_zones_mostoles = checkPositions(sample_coordinates['Móstoles'], prefix=WORK_FOLDER)

# %%
comparePlaces(df, health_zones_mostoles,dataset='zonas')

# %%
plotPlaces(df, health_zones_mostoles, agg_factor=1, dataset='zonas')
# Out:
# Error en Parque Loranca!!: Axis limits cannot be NaN or Inf
# Error en Barcelona!!: Axis limits cannot be NaN or Inf
# Error en La Princesa!!: Axis limits cannot be NaN or Inf
# Error en Presentación Sabio!!: Axis limits cannot be NaN or Inf
# Error en Miguel Servet!!: Axis limits cannot be NaN or Inf
# Error en El Soto!!: Axis limits cannot be NaN or Inf
# Error en Dos de Mayo!!: Axis limits cannot be NaN or Inf
# Error en Alcalde Bartolomé González!!: Axis limits cannot be NaN or Inf
# Error en Doctor Luengo Rodríguez!!: Axis limits cannot be NaN or Inf
# Error en Felipe II!!: Axis limits cannot be NaN or Inf

# %% [markdown]
# ### Conclusion

# %% [markdown]
# A la vista de los resultados de este notebook y el alterior [CovidMadrid](CovidMadrid.ipynb), dado que la incidencia parece tener cierta homogeneidad por zonas en ambas poblaciones, solo cabe pensar que la diferencia se debe a la diferencia del momento en el que se aplicó el confinamiento. En el momento de decretarse el mismo, el nivel de penetración en Leganés debía ser mucho mayor que el de Getafe.

# %% [markdown]
# # Fin de la visualización
